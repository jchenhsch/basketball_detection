# %%
# customized training for yolov9c
# credit to dataset here: https://universe.roboflow.com/computer-vision-d5fjh/basketball-detection-dn6fg/dataset/4
# !yolo task=detect mode=train epochs=3 data=data.yaml model=yolov8s

# to test the best.pt weight after training run:
#!yolo task=detect mode=predict model=best.pt show=True conf=0.5 source = frames/img0223.png

# to resume training from the last checkpoint:
# !yolo train resume model=runs/detect/train/weights/last.pt (replace path to the last .pt file)

# use model.track to save all the models into a video file:
# model.track(src .....)

# %%
# importing the necessary libraries
import shutil
from ultralytics import YOLO
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import cv2
from skimage.metrics import structural_similarity as ssim
from PIL import Image
import os

# %%
# Build a YOLOv8s model from pretrained weight
# yolo model trained on 9c, 100 epochs on GCP V100 deep learning instance

model = YOLO('weights/best9c_100.pt')
# Display model information (optional)
model.info()
# Out:
# YOLOv9c summary: 618 layers, 25531545 parameters, 0 gradients, 103.7 GFLOPs
# (618, 25531545, 0, 103.69152)

# %%
# define a helper which will parse the output of yolo
def yolo_model_prediction(frame, yolo_model):
    # Perform model prediction
    results = yolo_model(frame)

    # Extract bounding boxes, classes, and confidence scores
    boxes = results[0].boxes.xyxy.tolist()
    classes = results[0].boxes.cls.tolist()
    confidences = results[0].boxes.conf.tolist()

    # Extract class names
    names = results[0].names

    # Format results
    yolo_results = []
    for bbox, cls, conf in zip(boxes, classes, confidences):
        x1, y1, x2, y2 = map(int, bbox)
        class_name = names[int(cls)]
        yolo_results.append({'class': class_name, 'confidence': conf, 'bbox': (x1, y1, x2, y2)})

    return yolo_results

# %%
# a helper which takes in a frame, output the danger zones and goals in the frame
def get_zones(yolo_results,frame):
    image_width, image_height = frame.size

    # Find the basket bounding box
    basket_bbox = None
    for result in yolo_results:
        if result['class'] == "basket":
            basket_bbox = result['bbox']
            break

    if basket_bbox is None:
        return None, None

    basket_center_x = (basket_bbox[0] + basket_bbox[2]) // 2
    basket_center_y = (basket_bbox[1] + basket_bbox[3]) // 2

    danger_region = {
        'x1': max(0, basket_center_x - 60),
        'y1': max(0, basket_center_y - 80),
        'x2': min(image_width, basket_center_x + 60),
        'y2': min(image_height, basket_center_y)
    }

    goal_zone = {
        'x1': max(0, basket_center_x - 35),
        'y1': basket_center_y,
        'x2': min(image_width, basket_center_x + 35),
        'y2': min(image_height, basket_center_y + 80)
    }

    return danger_region, goal_zone

# %%
# extract player ground locations from yolo results
def extract_player_locations(yolo_results):
    player_locations = []
    for result in yolo_results:
        if result['class'] == "person":
            x1, y1, x2, y2 = result['bbox']
            player_loc_x = (x1 + x2) // 2
            player_loc_y = y2
            player_locations.append((player_loc_x, player_loc_y))
    return player_locations

# %%
# a helper to keep track of basketball locations in a frame
def extract_ball_locations(yolo_results):
    ball_locations = []
    for result in yolo_results:
        if result['class'] == "ball" or result['class'] == "sport ball":
            x1, y1, x2, y2 = result['bbox']
            ball_center_x = (x1 + x2) // 2
            ball_center_y = (y1 + y2) // 2
            ball_locations.append((ball_center_x, ball_center_y))
    return ball_locations

# %%
# a helper determine if the ball in safe / danger zone
def check_ball_zone(ball_location, danger_zone, goal_zone):
    if ball_location is None:
        return ""
    ball_x, ball_y = ball_location

    if danger_zone['x1'] <= ball_x <= danger_zone['x2'] and \
       danger_zone['y1'] <= ball_y <= danger_zone['y2']:
        return "danger"
    elif goal_zone['x1'] <= ball_x <= goal_zone['x2'] and \
         goal_zone['y1'] <= ball_y <= goal_zone['y2']:
        return "safe"
    else:
        return "none"

# %%
def calculate_distance(point1, point2):
    x1, y1 = map(int, point1)
    x2, y2 = map(int, point2)
    return ((x2 - x1) ** 2 + (y2 - y1) ** 2) ** 0.5

# %%
def update_numbers(ball_locations, prev_ball_locations, danger_zone,goal_zone):

    inc_goals = 0
    inc_attempts = 0
    for prev_ball_location in prev_ball_locations:
        closest_distance = float('inf')
        closest_ball_location = None
        for ball_location in ball_locations:
            # find the closet ball location to the previous ball location
            # print(ball_location)
            # print(prev_ball_location)
            distance = calculate_distance(prev_ball_location, ball_location)
            if distance < closest_distance:
                closest_distance = distance
                closest_ball_location = ball_location

        # Check if the closest ball location is in the danger zone
        prev_ball_zone = check_ball_zone(prev_ball_location, danger_zone, goal_zone)
        curr_ball_zone = check_ball_zone(closest_ball_location, danger_zone, goal_zone)
        # print(prev_ball_zone)
        # print(curr_ball_zone)
        if ((prev_ball_zone == 'danger') and (curr_ball_zone == 'none')):
            inc_attempts += 1
        elif ((prev_ball_zone == 'danger') and (curr_ball_zone == 'safe')):
            inc_attempts += 1
            inc_goals +=1
    return inc_goals, inc_attempts

# %%
def map_point_to_top_view(pt):
    pts_frame =np.array([[252,243],[346,250],[482,257],[682,269],[144,272],[224,282],[339,293],[0,271],[95,300],[650,338]],dtype=np.float32)
    pts_top_view = np.array([[66,0],[270,0],[435,0],[635,0],[265,225],[350,225],[435,225],[66,347],[353,347],[635,347]],dtype=np.float32)

    # Compute homography matrix
    H, _ = cv2.findHomography(pts_frame, pts_top_view)
    
    # Map the point to top view
    pt = np.array([pt], dtype=np.float32)
    mapped_pt = cv2.perspectiveTransform(pt.reshape(-1, 1, 2), H)
    return mapped_pt[0][0]

# %%
def annotate_frame(frame, yolo_results, attempts, goals,closest_player_loc,is_goal, is_attempt,top_view_img='src/top_view_court_img.png'):
    annotated_frame = frame.copy()
    
    # frame for mapping, resized two image temporarily
    top_view_img = cv2.imread(top_view_img)
    top_view_img = cv2.resize(top_view_img, (700, 400))


    resized_width, resized_height = 700, 400
    
    width, height = annotated_frame.size

    # Calculate scaling factors
    scale_x = resized_width / width
    scale_y = resized_height / height

    # Print attempts and goals in bottom-left corner
    text_attempts = f"Attempts: {attempts}"
    text_goals = f"Goals: {goals}"
    
    # Convert the PIL Image to a NumPy array
    annotated_frame = np.array(annotated_frame)

    # Use the NumPy array in cv2.putText
    cv2.putText(annotated_frame, text_attempts, (10, height - 60), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(annotated_frame, text_goals, (10, height - 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)


    # Draw bounding boxes around players
    for result in yolo_results:
        if result['class'] == "person":
            x1, y1, x2, y2 = result['bbox']
            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (255, 0, 0), 2)

    # Draw bounding box around the basket
    for result in yolo_results:
        if result['class'] == "basket":
            x1, y1, x2, y2 = result['bbox']
            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 255), 2)

    # Draw circles around ball locations
    ball_locations = extract_ball_locations(yolo_results)
    for ball_location in ball_locations:
        cv2.circle(annotated_frame, ball_location, 5, (0, 0, 255), -1)

    # Draw danger region and goal zone
    danger_region, goal_zone = get_zones(yolo_results, frame)
    if danger_region is not None:
        cv2.rectangle(annotated_frame, (danger_region['x1'], danger_region['y1']), (danger_region['x2'], danger_region['y2']), (0, 0, 255), 2)
    if goal_zone is not None:
        cv2.rectangle(annotated_frame, (goal_zone['x1'], goal_zone['y1']), (goal_zone['x2'], goal_zone['y2']), (0, 255, 0), 2)
    
   # annotate the closet player location as a circle in the frame
    top_view_img_mapped= None
    if closest_player_loc is None or (is_goal == False and is_attempt == False):
        
        if top_view_img_mapped is None:
            # Resize the top view image to a smaller size
            resized_top_view_img = cv2.resize(top_view_img, (0, 0), fx=0.5, fy=0.5)
        
            # Get the dimensions of the frame and resized top view image
            frame_height, frame_width, _ = annotated_frame.shape
            resized_height, resized_width, _ = resized_top_view_img.shape

            annotated_frame[:resized_height, frame_width - resized_width:] = resized_top_view_img

        return annotated_frame
    else:
        if is_goal == True:
            # scale from original frame to resized frame 700,400
            scaled_point = (int(closest_player_loc[0] * scale_x), int(closest_player_loc[1] * scale_y))
            # map the scaled point to the top view image
            mapped_point = map_point_to_top_view(scaled_point)
            x,y = mapped_point
            x = int(x)
            y = int(y)

            top_view_img_mapped= cv2.circle(top_view_img, (x,y), 5, (0, 255, 0), -1)
            # Resize the top view image to a smaller size
            resized_top_view_img = cv2.resize(top_view_img_mapped, (0, 0), fx=0.5, fy=0.5)
            
            # Get the dimensions of the frame and resized top view image
            frame_height, frame_width, _ = annotated_frame.shape
            resized_height, resized_width, _ = resized_top_view_img.shape

            annotated_frame[:resized_height, frame_width - resized_width:] = resized_top_view_img


        if is_attempt == True:
            scaled_point = (int(closest_player_loc[0] * scale_x), int(closest_player_loc[1] * scale_y))
            mapped_point = map_point_to_top_view(scaled_point)
            
            x,y = mapped_point
            x = int(x)
            y = int(y)
            
            # annotate the closest player location in the top view non-resized image
            top_view_img_m= cv2.line(top_view_img, (x - 5, y - 5), (x + 5, y + 5), (255, 0, 0), 2)
            top_view_img_mapped= cv2.line(top_view_img_m, (x + 5, y - 5), (x - 5, y + 5), (255, 0, 0), 2)

            # Resize the top view image to a smaller size
            resized_top_view_img = cv2.resize(top_view_img_mapped, (0, 0), fx=0.5, fy=0.5)
            
            # Get the dimensions of the frame and resized top view image
            frame_height, frame_width, _ = annotated_frame.shape
            resized_height, resized_width, _ = resized_top_view_img.shape

            annotated_frame[:resized_height, frame_width - resized_width:] = resized_top_view_img
        
        # update the top view image in the directory
        cv2.imwrite('src/top_view_court_img.png', resized_top_view_img)
            
    return annotated_frame

# %%
def find_closest_player_to_ball(yolo_results, ball_locations):
    closest_player = None
    for result in yolo_results:
        for ball_location in ball_locations:
            if result['class'] == "person":
                x1, y1, x2, y2 = result['bbox']
                if x1 <= ball_location[0] <= x2 and y1 <= ball_location[1] <= y2:
                    player_loc_x = (x1 + x2) // 2
                    player_loc_y = y2
                    closest_player = (player_loc_x, player_loc_y)
                    break
    return closest_player

# %%
# read from frame directory and detect objects using yolo
def check_goal_from_frame_dir(frame_directory, model, res_frame_dir):
    # init the goal and attempts
    goals = 0
    attempts = 0

    # read all frames in the directory
    fst_img_path = os.path.join(frame_directory, "img0001.png")
    frame = Image.open(fst_img_path)

    # extract basket location, ball location in the first frame
    yolo_results = yolo_model_prediction(frame, model)
    prev_ball_locations = extract_ball_locations(yolo_results)
    danger_region, goal_zone = get_zones(yolo_results, frame)

    # # extract player location in the first frame
    # player_locations = extract_player_locations(yolo_results)
    
    # find the closest player to the ball in the first frame
    prev_closest_player_loc = find_closest_player_to_ball(yolo_results, prev_ball_locations)
    closest_player_loc = None

    annotated_frame = annotate_frame(frame, yolo_results, attempts, goals, closest_player_loc, is_attempt=False, is_goal=False)
    save_path = os.path.join(res_frame_dir, "img0001.png")
    cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR, annotated_frame)
    cv2.imwrite(save_path, annotated_frame)

    file_names = os.listdir(frame_directory)
    file_names.sort()
    # print(file_names)
    for file_name in file_names:
        is_goal = False
        is_attempt = False
        if file_name.endswith(".jpg") or file_name.endswith(".png"):
            if file_name == "img0001.png":
                continue
            # extract ball location in current frame
            frame =Image.open(os.path.join(frame_directory, file_name))
            yolo_results = yolo_model_prediction(frame, model)
            ball_locations = extract_ball_locations(yolo_results)         
            inc_goals, inc_attempts = update_numbers(ball_locations,prev_ball_locations,danger_region, goal_zone)
            
            if inc_goals>0:
                is_goal = True
            if inc_attempts>0:
                is_attempt = True

            goals += inc_goals
            attempts += inc_attempts
            # annotate the frame and save the annotated frame
            
            # extract player location
            player_locations = extract_player_locations(yolo_results)
            # update the closest player to the ball
            closest_player_loc = find_closest_player_to_ball(yolo_results,ball_locations)
            
            if closest_player_loc is None:
                closest_player_loc = prev_closest_player_loc
            else:
                prev_closest_player_loc = closest_player_loc

            print(closest_player_loc)

            annotated_frame = annotate_frame(frame, yolo_results, attempts, goals, closest_player_loc,is_goal, is_attempt)
            
            save_path = os.path.join(res_frame_dir, file_name)
            cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR, annotated_frame)
            cv2.imwrite(save_path, annotated_frame)

            # if lose track of ball in current frame don't update prev_ball_locations
            if len(ball_locations) != 0:
                prev_ball_locations = ball_locations

    # return goal and attempts
    return goals, attempts

# %%
frame_dir = 'frames'
res_frame_dir = 'res_frames'
try:
    shutil.rmtree(res_frame_dir)
except:
    pass
os.makedirs(res_frame_dir)
goals, attempts = check_goal_from_frame_dir(frame_dir,model,res_frame_dir)
print(goals, attempts)
# Out:
# 0: 384x640 1 ball, 1 basket, 3 persons, 157.6ms
# Speed: 1.4ms preprocess, 157.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 basket, 3 persons, 148.3ms
# Speed: 1.0ms preprocess, 148.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# None
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.0ms
# Speed: 0.9ms preprocess, 151.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# None
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.0ms
# Speed: 1.0ms preprocess, 147.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# None
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.1ms
# Speed: 1.0ms preprocess, 145.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# None
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.8ms
# Speed: 1.0ms preprocess, 150.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# None
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 163.9ms
# Speed: 1.1ms preprocess, 163.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# None
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.6ms
# Speed: 1.0ms preprocess, 146.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# None
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.3ms
# Speed: 1.1ms preprocess, 143.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (340, 532)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.3ms
# Speed: 1.1ms preprocess, 149.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (340, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.8ms
# Speed: 1.0ms preprocess, 147.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (340, 531)
#
# 0: 384x640 1 basket, 3 persons, 147.8ms
# Speed: 1.1ms preprocess, 147.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (340, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 160.6ms
# Speed: 1.1ms preprocess, 160.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (340, 531)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 148.6ms
# Speed: 1.6ms preprocess, 148.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (325, 531)
#
# 0: 384x640 1 basket, 3 persons, 139.9ms
# Speed: 0.9ms preprocess, 139.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (325, 531)
#
# 0: 384x640 1 basket, 3 persons, 146.2ms
# Speed: 1.1ms preprocess, 146.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (325, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.3ms
# Speed: 1.0ms preprocess, 148.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (324, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.2ms
# Speed: 1.0ms preprocess, 146.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (321, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.5ms
# Speed: 1.0ms preprocess, 146.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (317, 531)
#
# 0: 384x640 1 basket, 3 persons, 145.3ms
# Speed: 1.0ms preprocess, 145.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (317, 531)
#
# 0: 384x640 1 basket, 3 persons, 140.3ms
# Speed: 1.1ms preprocess, 140.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (317, 531)
#
# 0: 384x640 1 basket, 3 persons, 145.3ms
# Speed: 1.1ms preprocess, 145.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (317, 531)
#
# 0: 384x640 1 basket, 3 persons, 174.6ms
# Speed: 12.2ms preprocess, 174.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (317, 531)
#
# 0: 384x640 1 basket, 3 persons, 169.8ms
# Speed: 1.0ms preprocess, 169.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (317, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.2ms
# Speed: 1.0ms preprocess, 145.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (302, 527)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 156.0ms
# Speed: 1.0ms preprocess, 156.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (302, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 142.1ms
# Speed: 1.0ms preprocess, 142.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (302, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 142.3ms
# Speed: 1.0ms preprocess, 142.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (302, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.3ms
# Speed: 1.0ms preprocess, 145.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 basket, 3 persons, 182.8ms
# Speed: 1.0ms preprocess, 182.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 156.9ms
# Speed: 1.1ms preprocess, 156.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.2ms
# Speed: 1.1ms preprocess, 145.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.4ms
# Speed: 1.1ms preprocess, 143.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.8ms
# Speed: 1.1ms preprocess, 144.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.4ms
# Speed: 1.1ms preprocess, 143.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.0ms
# Speed: 1.0ms preprocess, 148.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.2ms
# Speed: 1.0ms preprocess, 144.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 165.9ms
# Speed: 0.9ms preprocess, 165.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.2ms
# Speed: 1.0ms preprocess, 143.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.6ms
# Speed: 1.0ms preprocess, 150.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.2ms
# Speed: 0.9ms preprocess, 147.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.1ms
# Speed: 1.2ms preprocess, 147.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 142.7ms
# Speed: 1.3ms preprocess, 142.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.2ms
# Speed: 1.1ms preprocess, 144.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 141.6ms
# Speed: 1.3ms preprocess, 141.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 177.6ms
# Speed: 1.0ms preprocess, 177.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.6ms
# Speed: 1.1ms preprocess, 144.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.8ms
# Speed: 1.0ms preprocess, 148.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.7ms
# Speed: 1.0ms preprocess, 147.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.1ms
# Speed: 1.0ms preprocess, 148.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 159.3ms
# Speed: 2.8ms preprocess, 159.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.9ms
# Speed: 1.0ms preprocess, 145.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.0ms
# Speed: 1.0ms preprocess, 149.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 basket, 3 persons, 172.4ms
# Speed: 1.0ms preprocess, 172.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (300, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.7ms
# Speed: 1.2ms preprocess, 148.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.0ms
# Speed: 1.0ms preprocess, 147.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.9ms
# Speed: 1.0ms preprocess, 144.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 basket, 3 persons, 150.3ms
# Speed: 1.0ms preprocess, 150.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.8ms
# Speed: 1.1ms preprocess, 145.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.4ms
# Speed: 1.0ms preprocess, 149.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.7ms
# Speed: 1.0ms preprocess, 146.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.9ms
# Speed: 0.9ms preprocess, 146.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.6ms
# Speed: 1.1ms preprocess, 145.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.0ms
# Speed: 1.0ms preprocess, 143.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 basket, 3 persons, 150.5ms
# Speed: 1.0ms preprocess, 150.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 basket, 3 persons, 143.5ms
# Speed: 1.0ms preprocess, 143.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (533, 475)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.3ms
# Speed: 1.0ms preprocess, 146.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (244, 527)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.8ms
# Speed: 1.0ms preprocess, 148.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (244, 527)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.0ms
# Speed: 1.3ms preprocess, 148.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (244, 527)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.0ms
# Speed: 1.0ms preprocess, 149.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (239, 527)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.4ms
# Speed: 1.0ms preprocess, 144.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 basket, 3 persons, 143.3ms
# Speed: 1.0ms preprocess, 143.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 basket, 3 persons, 144.5ms
# Speed: 1.0ms preprocess, 144.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 basket, 3 persons, 142.4ms
# Speed: 0.9ms preprocess, 142.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 basket, 3 persons, 167.0ms
# Speed: 0.9ms preprocess, 167.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 basket, 3 persons, 144.8ms
# Speed: 1.1ms preprocess, 144.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 basket, 3 persons, 144.7ms
# Speed: 1.1ms preprocess, 144.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 basket, 3 persons, 145.8ms
# Speed: 1.2ms preprocess, 145.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 basket, 3 persons, 159.2ms
# Speed: 1.4ms preprocess, 159.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (240, 527)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.8ms
# Speed: 1.3ms preprocess, 152.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (266, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.7ms
# Speed: 1.0ms preprocess, 146.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (266, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.7ms
# Speed: 0.9ms preprocess, 145.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (275, 530)
#
# 0: 384x640 1 basket, 3 persons, 142.9ms
# Speed: 0.9ms preprocess, 142.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (275, 530)
#
# 0: 384x640 1 basket, 3 persons, 147.7ms
# Speed: 1.0ms preprocess, 147.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (275, 530)
#
# 0: 384x640 1 basket, 3 persons, 147.1ms
# Speed: 1.0ms preprocess, 147.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (275, 530)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 157.9ms
# Speed: 1.1ms preprocess, 157.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.9ms
# Speed: 1.2ms preprocess, 144.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 basket, 3 persons, 143.6ms
# Speed: 1.0ms preprocess, 143.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 basket, 3 persons, 143.3ms
# Speed: 1.1ms preprocess, 143.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.6ms
# Speed: 1.1ms preprocess, 152.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.7ms
# Speed: 1.0ms preprocess, 148.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.9ms
# Speed: 1.0ms preprocess, 151.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.0ms
# Speed: 1.0ms preprocess, 146.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.0ms
# Speed: 1.0ms preprocess, 146.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.1ms
# Speed: 1.1ms preprocess, 145.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.9ms
# Speed: 1.2ms preprocess, 146.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.8ms
# Speed: 1.0ms preprocess, 146.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.5ms
# Speed: 1.0ms preprocess, 147.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.1ms
# Speed: 1.0ms preprocess, 147.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.2ms
# Speed: 1.1ms preprocess, 153.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.5ms
# Speed: 1.0ms preprocess, 145.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.3ms
# Speed: 1.4ms preprocess, 148.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.1ms
# Speed: 1.0ms preprocess, 146.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.5ms
# Speed: 0.9ms preprocess, 144.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.8ms
# Speed: 1.0ms preprocess, 143.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.0ms
# Speed: 1.0ms preprocess, 147.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 187.7ms
# Speed: 1.0ms preprocess, 187.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 140.3ms
# Speed: 0.9ms preprocess, 140.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.2ms
# Speed: 1.1ms preprocess, 148.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.6ms
# Speed: 1.0ms preprocess, 150.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.1ms
# Speed: 1.0ms preprocess, 146.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.7ms
# Speed: 1.0ms preprocess, 147.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.7ms
# Speed: 1.1ms preprocess, 145.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.8ms
# Speed: 1.0ms preprocess, 150.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 180.9ms
# Speed: 1.2ms preprocess, 180.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.3ms
# Speed: 1.1ms preprocess, 146.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 145.8ms
# Speed: 1.0ms preprocess, 145.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.8ms
# Speed: 0.9ms preprocess, 143.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.3ms
# Speed: 0.9ms preprocess, 152.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 153.7ms
# Speed: 1.0ms preprocess, 153.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.1ms
# Speed: 1.0ms preprocess, 150.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.1ms
# Speed: 1.0ms preprocess, 149.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.6ms
# Speed: 1.1ms preprocess, 146.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.1ms
# Speed: 1.0ms preprocess, 149.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 164.8ms
# Speed: 1.1ms preprocess, 164.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.3ms
# Speed: 1.1ms preprocess, 151.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.8ms
# Speed: 1.1ms preprocess, 147.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.8ms
# Speed: 1.0ms preprocess, 143.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.3ms
# Speed: 1.2ms preprocess, 143.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.6ms
# Speed: 1.1ms preprocess, 147.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.4ms
# Speed: 1.1ms preprocess, 147.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.9ms
# Speed: 1.2ms preprocess, 150.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 165.0ms
# Speed: 1.6ms preprocess, 165.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.2ms
# Speed: 1.1ms preprocess, 148.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (295, 528)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 148.7ms
# Speed: 1.3ms preprocess, 148.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (650, 487)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.3ms
# Speed: 1.0ms preprocess, 149.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (653, 487)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.5ms
# Speed: 1.1ms preprocess, 148.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (648, 487)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 169.2ms
# Speed: 1.2ms preprocess, 169.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (577, 480)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.5ms
# Speed: 1.1ms preprocess, 147.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (578, 480)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.8ms
# Speed: 1.0ms preprocess, 143.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (631, 487)
#
# 0: 384x640 1 ball, 1 basket, 4 persons, 147.3ms
# Speed: 1.1ms preprocess, 147.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.5ms
# Speed: 1.0ms preprocess, 154.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.4ms
# Speed: 1.1ms preprocess, 146.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.7ms
# Speed: 1.0ms preprocess, 144.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.0ms
# Speed: 1.4ms preprocess, 144.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.6ms
# Speed: 1.3ms preprocess, 149.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.2ms
# Speed: 1.0ms preprocess, 148.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 160.2ms
# Speed: 1.0ms preprocess, 160.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.9ms
# Speed: 1.2ms preprocess, 152.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.0ms
# Speed: 1.0ms preprocess, 153.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 169.7ms
# Speed: 1.0ms preprocess, 169.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.8ms
# Speed: 1.4ms preprocess, 151.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 basket, 3 persons, 150.2ms
# Speed: 1.0ms preprocess, 150.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (592, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.7ms
# Speed: 1.2ms preprocess, 149.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (291, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.2ms
# Speed: 1.0ms preprocess, 154.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (286, 531)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 156.3ms
# Speed: 1.0ms preprocess, 156.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (286, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.6ms
# Speed: 1.0ms preprocess, 150.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (285, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.4ms
# Speed: 1.2ms preprocess, 151.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (283, 532)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.7ms
# Speed: 1.0ms preprocess, 153.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (278, 532)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.0ms
# Speed: 1.4ms preprocess, 153.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (275, 532)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.5ms
# Speed: 1.0ms preprocess, 151.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (273, 531)
#
# 0: 384x640 1 basket, 3 persons, 155.8ms
# Speed: 1.5ms preprocess, 155.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (273, 531)
#
# 0: 384x640 1 basket, 3 persons, 183.3ms
# Speed: 1.0ms preprocess, 183.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# (273, 531)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.3ms
# Speed: 1.1ms preprocess, 152.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (271, 529)
#
# 0: 384x640 1 basket, 3 persons, 149.9ms
# Speed: 1.1ms preprocess, 149.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (271, 529)
#
# 0: 384x640 1 basket, 3 persons, 155.9ms
# Speed: 1.1ms preprocess, 155.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (271, 529)
#
# 0: 384x640 1 basket, 3 persons, 147.8ms
# Speed: 1.0ms preprocess, 147.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (271, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.0ms
# Speed: 1.1ms preprocess, 148.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.2ms
# Speed: 1.0ms preprocess, 148.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 141.3ms
# Speed: 1.0ms preprocess, 141.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 basket, 3 persons, 156.7ms
# Speed: 1.0ms preprocess, 156.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.5ms
# Speed: 1.1ms preprocess, 150.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.6ms
# Speed: 1.3ms preprocess, 149.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 163.9ms
# Speed: 1.0ms preprocess, 163.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.0ms
# Speed: 1.4ms preprocess, 153.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.3ms
# Speed: 1.1ms preprocess, 154.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 basket, 3 persons, 151.2ms
# Speed: 1.0ms preprocess, 151.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.0ms
# Speed: 1.0ms preprocess, 150.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.1ms
# Speed: 1.0ms preprocess, 149.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.9ms
# Speed: 1.0ms preprocess, 148.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.9ms
# Speed: 1.1ms preprocess, 150.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.0ms
# Speed: 1.1ms preprocess, 145.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.9ms
# Speed: 0.9ms preprocess, 147.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.0ms
# Speed: 0.9ms preprocess, 145.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.5ms
# Speed: 1.0ms preprocess, 144.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.0ms
# Speed: 0.9ms preprocess, 145.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.8ms
# Speed: 1.0ms preprocess, 149.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.3ms
# Speed: 1.0ms preprocess, 152.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.5ms
# Speed: 1.0ms preprocess, 154.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.8ms
# Speed: 1.1ms preprocess, 145.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 155.3ms
# Speed: 1.0ms preprocess, 155.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.5ms
# Speed: 0.9ms preprocess, 150.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.3ms
# Speed: 1.0ms preprocess, 149.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.1ms
# Speed: 1.0ms preprocess, 148.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.0ms
# Speed: 0.9ms preprocess, 148.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.6ms
# Speed: 1.0ms preprocess, 145.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.4ms
# Speed: 1.0ms preprocess, 146.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.4ms
# Speed: 1.0ms preprocess, 149.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.6ms
# Speed: 0.9ms preprocess, 145.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.1ms
# Speed: 1.1ms preprocess, 146.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 basket, 3 persons, 146.4ms
# Speed: 1.0ms preprocess, 146.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.4ms
# Speed: 1.0ms preprocess, 146.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.8ms
# Speed: 1.1ms preprocess, 147.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 142.1ms
# Speed: 1.0ms preprocess, 142.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 basket, 3 persons, 147.7ms
# Speed: 1.0ms preprocess, 147.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 basket, 3 persons, 146.1ms
# Speed: 1.0ms preprocess, 146.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 147.5ms
# Speed: 1.1ms preprocess, 147.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.9ms
# Speed: 0.9ms preprocess, 151.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 154.1ms
# Speed: 1.0ms preprocess, 154.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.2ms
# Speed: 0.9ms preprocess, 150.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.6ms
# Speed: 1.2ms preprocess, 150.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 164.4ms
# Speed: 1.2ms preprocess, 164.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.2ms
# Speed: 1.0ms preprocess, 154.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 basket, 3 persons, 151.0ms
# Speed: 1.1ms preprocess, 151.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.1ms
# Speed: 1.0ms preprocess, 150.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (269, 529)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 161.8ms
# Speed: 1.2ms preprocess, 161.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (617, 473)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.4ms
# Speed: 1.4ms preprocess, 148.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (620, 472)
#
# 0: 384x640 1 basket, 3 persons, 153.1ms
# Speed: 1.1ms preprocess, 153.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (620, 472)
#
# 0: 384x640 1 basket, 3 persons, 149.1ms
# Speed: 1.1ms preprocess, 149.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (620, 472)
#
# 0: 384x640 1 basket, 3 persons, 152.5ms
# Speed: 1.0ms preprocess, 152.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (620, 472)
#
# 0: 384x640 1 basket, 3 persons, 154.7ms
# Speed: 1.3ms preprocess, 154.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (620, 472)
#
# 0: 384x640 1 basket, 3 persons, 155.1ms
# Speed: 1.0ms preprocess, 155.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (620, 472)
#
# 0: 384x640 1 basket, 3 persons, 150.5ms
# Speed: 1.1ms preprocess, 150.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (620, 472)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 160.8ms
# Speed: 1.1ms preprocess, 160.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (627, 473)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 159.3ms
# Speed: 1.0ms preprocess, 159.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (626, 473)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 165.5ms
# Speed: 1.2ms preprocess, 165.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (623, 473)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 155.1ms
# Speed: 1.1ms preprocess, 155.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (623, 473)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 150.4ms
# Speed: 1.2ms preprocess, 150.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (620, 473)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.9ms
# Speed: 1.1ms preprocess, 153.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.3ms
# Speed: 1.0ms preprocess, 151.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 150.6ms
# Speed: 1.3ms preprocess, 150.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.0ms
# Speed: 1.0ms preprocess, 152.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.5ms
# Speed: 1.0ms preprocess, 150.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 basket, 3 persons, 152.4ms
# Speed: 1.1ms preprocess, 152.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.4ms
# Speed: 1.0ms preprocess, 149.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 basket, 3 persons, 165.1ms
# Speed: 1.1ms preprocess, 165.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.0ms
# Speed: 1.3ms preprocess, 154.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.4ms
# Speed: 1.0ms preprocess, 152.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.3ms
# Speed: 1.1ms preprocess, 153.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 1 basket, 3 persons, 155.2ms
# Speed: 1.0ms preprocess, 155.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (194, 485)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 149.3ms
# Speed: 1.0ms preprocess, 149.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (222, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.3ms
# Speed: 1.2ms preprocess, 147.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (222, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 157.5ms
# Speed: 1.2ms preprocess, 157.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (222, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.6ms
# Speed: 1.2ms preprocess, 153.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (205, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 169.0ms
# Speed: 12.1ms preprocess, 169.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (205, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.7ms
# Speed: 1.0ms preprocess, 151.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (199, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.8ms
# Speed: 1.1ms preprocess, 152.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (200, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.1ms
# Speed: 1.1ms preprocess, 153.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (199, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 155.5ms
# Speed: 1.1ms preprocess, 155.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (196, 482)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.1ms
# Speed: 1.1ms preprocess, 153.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (196, 483)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.5ms
# Speed: 1.3ms preprocess, 150.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (196, 483)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.5ms
# Speed: 1.0ms preprocess, 151.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (196, 483)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.6ms
# Speed: 1.1ms preprocess, 154.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 154.7ms
# Speed: 0.9ms preprocess, 154.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 159.0ms
# Speed: 1.1ms preprocess, 159.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 155.7ms
# Speed: 1.1ms preprocess, 155.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 153.1ms
# Speed: 1.1ms preprocess, 153.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 150.4ms
# Speed: 1.0ms preprocess, 150.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 155.2ms
# Speed: 1.1ms preprocess, 155.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 148.9ms
# Speed: 1.0ms preprocess, 148.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.2ms
# Speed: 1.0ms preprocess, 150.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.5ms
# Speed: 0.9ms preprocess, 149.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.1ms
# Speed: 1.6ms preprocess, 149.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.0ms
# Speed: 1.1ms preprocess, 148.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.2ms
# Speed: 1.1ms preprocess, 149.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.3ms
# Speed: 1.1ms preprocess, 145.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.5ms
# Speed: 1.2ms preprocess, 149.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.1ms
# Speed: 0.9ms preprocess, 146.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.4ms
# Speed: 1.1ms preprocess, 147.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.2ms
# Speed: 1.1ms preprocess, 149.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.4ms
# Speed: 1.0ms preprocess, 153.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.5ms
# Speed: 1.1ms preprocess, 152.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 163.4ms
# Speed: 1.8ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.0ms
# Speed: 1.0ms preprocess, 154.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.6ms
# Speed: 0.9ms preprocess, 146.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 148.8ms
# Speed: 1.0ms preprocess, 148.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 152.8ms
# Speed: 1.0ms preprocess, 152.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 2 baskets, 3 persons, 149.6ms
# Speed: 1.2ms preprocess, 149.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 2 baskets, 3 persons, 150.7ms
# Speed: 0.9ms preprocess, 150.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 141.3ms
# Speed: 1.0ms preprocess, 141.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.8ms
# Speed: 1.1ms preprocess, 148.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 151.0ms
# Speed: 1.1ms preprocess, 151.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.7ms
# Speed: 1.0ms preprocess, 152.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 154.2ms
# Speed: 1.4ms preprocess, 154.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 155.2ms
# Speed: 1.0ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 155.8ms
# Speed: 1.2ms preprocess, 155.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 144.5ms
# Speed: 1.1ms preprocess, 144.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 148.8ms
# Speed: 1.0ms preprocess, 148.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 145.2ms
# Speed: 1.2ms preprocess, 145.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 144.4ms
# Speed: 1.1ms preprocess, 144.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 152.0ms
# Speed: 1.1ms preprocess, 152.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 basket, 3 persons, 149.8ms
# Speed: 1.0ms preprocess, 149.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (211, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.1ms
# Speed: 1.1ms preprocess, 143.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (716, 492)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 144.3ms
# Speed: 0.9ms preprocess, 144.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (716, 492)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.6ms
# Speed: 1.0ms preprocess, 149.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (716, 492)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 149.6ms
# Speed: 0.9ms preprocess, 149.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# (716, 492)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 143.6ms
# Speed: 1.0ms preprocess, 143.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (716, 492)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 146.6ms
# Speed: 0.9ms preprocess, 146.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (631, 472)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 144.9ms
# Speed: 1.1ms preprocess, 144.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (630, 473)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 165.9ms
# Speed: 10.8ms preprocess, 165.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (182, 485)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.8ms
# Speed: 1.1ms preprocess, 148.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (632, 473)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 145.2ms
# Speed: 1.0ms preprocess, 145.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (632, 476)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 152.2ms
# Speed: 1.2ms preprocess, 152.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (632, 474)
#
# 0: 384x640 1 basket, 3 persons, 146.3ms
# Speed: 1.1ms preprocess, 146.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# (632, 474)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 150.6ms
# Speed: 1.0ms preprocess, 150.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (627, 473)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 148.0ms
# Speed: 1.0ms preprocess, 148.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# (621, 474)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 156.5ms
# Speed: 1.3ms preprocess, 156.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (621, 474)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 147.3ms
# Speed: 1.0ms preprocess, 147.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (621, 474)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 153.0ms
# Speed: 1.1ms preprocess, 153.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# (621, 474)
#
# 0: 384x640 1 ball, 1 basket, 3 persons, 151.8ms
# Speed: 1.2ms preprocess, 151.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (621, 474)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 150.0ms
# Speed: 1.2ms preprocess, 150.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (621, 474)
#
# 0: 384x640 2 balls, 1 basket, 3 persons, 147.8ms
# Speed: 1.0ms preprocess, 147.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# (621, 474)
# 3 4

# %%
# resemble the frames into a video using ffmpeg
# !ffmpeg -y -r 30 -i res_frames/img%04d.png -vf "scale=1280:-2" -c:v libx264 -pix_fmt yuv420p output.mp4
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'res_frames/img%04d.png':
#   Duration: 00:00:12.48, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1280x720, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14b00a000] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14b00a000] profile High, level 3.1
# [libx264 @ 0x14b00a000] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  312 fps=202 q=-1.0 Lsize=     965kB time=00:00:10.30 bitrate= 767.4kbits/s speed=6.66x
# video:961kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.448936%
# [libx264 @ 0x14b00a000] frame I:2     Avg QP:18.67  size: 75489
# [libx264 @ 0x14b00a000] frame P:102   Avg QP:20.69  size:  5915
# [libx264 @ 0x14b00a000] frame B:208   Avg QP:30.14  size:  1099
# [libx264 @ 0x14b00a000] consecutive B-frames:  7.7%  7.1%  9.6% 75.6%
# [libx264 @ 0x14b00a000] mb I  I16..4: 17.9% 43.9% 38.1%
# [libx264 @ 0x14b00a000] mb P  I16..4:  0.7%  0.6%  0.6%  P16..4: 16.4%  3.3%  2.7%  0.0%  0.0%    skip:75.6%
# [libx264 @ 0x14b00a000] mb B  I16..4:  0.1%  0.1%  0.1%  B16..8:  9.5%  1.0%  0.3%  direct: 0.2%  skip:88.8%  L0:39.2% L1:58.0% BI: 2.8%
# [libx264 @ 0x14b00a000] 8x8 transform intra:37.3% inter:57.1%
# [libx264 @ 0x14b00a000] coded y,uvDC,uvAC intra: 57.5% 64.9% 36.0% inter: 2.8% 5.1% 1.1%
# [libx264 @ 0x14b00a000] i16 v,h,dc,p: 39% 35%  8% 19%
# [libx264 @ 0x14b00a000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 36% 22%  3%  2%  3%  3%  3%  7%
# [libx264 @ 0x14b00a000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 41% 11%  3%  3%  3%  4%  3%  5%
# [libx264 @ 0x14b00a000] i8c dc,h,v,p: 33% 36% 28%  4%
# [libx264 @ 0x14b00a000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14b00a000] ref P L0: 77.4%  7.3% 11.2%  4.1%
# [libx264 @ 0x14b00a000] ref B L0: 88.1% 10.0%  1.9%
# [libx264 @ 0x14b00a000] ref B L1: 95.2%  4.8%
# [libx264 @ 0x14b00a000] kb/s:756.14
